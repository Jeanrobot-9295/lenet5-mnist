# %%
import sys, platform
import torch
import torchvision

print('python version:', sys.version)
print('platform:', platform.platform())
print('torch version:', torch.__version__)
print('torchvision version:', torchvision.__version__)

mps_ok = hasattr(torch.backends, 'mps') and torch.backends.mps.is_available()
print('mps available:', mps_ok)

device = torch.device("mps" if mps_ok else "cpu")
print("device:", device)

x = torch.randn(2, 3).to(device)
print("tensor device check:", x.device)
# Out:
# python version: 3.10.19 | packaged by conda-forge | (main, Oct 22 2025, 22:46:49) [Clang 19.1.7 ]
# platform: macOS-26.2-arm64-arm-64bit
# torch version: 2.2.2
# torchvision version: 0.17.2
# mps available: True
# device: mps
# tensor device check: mps:0
